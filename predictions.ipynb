# %%
from ultralytics import YOLO
model = YOLO('best.pt')

# %%
model.predict(source=0, show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 220.5ms
# 0: 480x640 (no detections), 616.3ms
# 0: 480x640 (no detections), 571.4ms
# 0: 480x640 (no detections), 232.5ms
# 0: 480x640 (no detections), 209.8ms
# 0: 480x640 (no detections), 133.1ms
# 0: 480x640 1 open_manhole, 145.9ms
# 0: 480x640 (no detections), 155.6ms
# 0: 480x640 (no detections), 132.6ms
# 0: 480x640 1 open_manhole, 145.0ms
# 0: 480x640 1 open_manhole, 143.4ms
# 0: 480x640 1 open_manhole, 140.7ms
# 0: 480x640 1 open_manhole, 129.4ms
# 0: 480x640 2 open_manholes, 142.5ms
# 0: 480x640 1 open_manhole, 134.9ms
# 0: 480x640 (no detections), 153.4ms
# 0: 480x640 (no detections), 185.5ms
# 0: 480x640 (no detections), 173.5ms
# 0: 480x640 2 open_manholes, 175.2ms
# 0: 480x640 1 open_manhole, 288.8ms
# 0: 480x640 1 open_manhole, 188.2ms
# 0: 480x640 1 open_manhole, 196.4ms
# 0: 480x640 1 open_manhole, 204.3ms
# 0: 480x640 1 open_manhole, 175.1ms
# 0: 480x640 1 open_manhole, 184.0ms
# 0: 480x640 1 open_manhole, 169.5ms
# 0: 480x640 1 open_manhole, 195.2ms
# 0: 480x640 1 open_manhole, 173.1ms
# 0: 480x640 1 open_manhole, 174.1ms
# 0: 480x640 (no detections), 174.8ms
# 0: 480x640 (no detections), 170.6ms
# 0: 480x640 (no detections), 172.5ms
# 0: 480x640 (no detections), 189.4ms
# 0: 480x640 (no detections), 176.1ms
# 0: 480x640 (no detections), 170.6ms
# 0: 480x640 (no detections), 175.1ms
# 0: 480x640 (no detections), 180.6ms
# 0: 480x640 (no detections), 178.0ms
# 0: 480x640 1 open_manhole, 178.6ms
# 0: 480x640 1 open_manhole, 181.3ms
# 0: 480x640 2 open_manholes, 173.9ms
# 0: 480x640 1 open_manhole, 166.7ms
# 0: 480x640 2 open_manholes, 174.9ms
# 0: 480x640 (no detections), 168.9ms
# 0: 480x640 (no detections), 173.2ms
# 0: 480x640 (no detections), 165.2ms
# 0: 480x640 (no detections), 172.1ms
# 0: 480x640 1 open_manhole, 177.4ms
# 0: 480x640 (no detections), 190.7ms
# 0: 480x640 1 crack, 195.8ms
# 0: 480x640 1 crack, 1 open_manhole, 164.9ms
# 0: 480x640 1 crack, 2 open_manholes, 174.4ms
# 0: 480x640 1 crack, 166.1ms
# 0: 480x640 1 crack, 182.8ms
# 0: 480x640 1 crack, 172.0ms
# 0: 480x640 1 crack, 147.6ms
# 0: 480x640 1 crack, 1 open_manhole, 177.4ms
# 0: 480x640 (no detections), 234.1ms
# 0: 480x640 (no detections), 175.5ms
# 0: 480x640 (no detections), 211.9ms
# 0: 480x640 (no detections), 235.9ms
# 0: 480x640 (no detections), 175.7ms
# 0: 480x640 (no detections), 516.1ms
# 0: 480x640 (no detections), 616.7ms
# 0: 480x640 1 open_manhole, 756.0ms
# 0: 480x640 1 open_manhole, 2231.3ms
# 0: 480x640 (no detections), 804.6ms
# 0: 480x640 (no detections), 392.0ms
# 0: 480x640 (no detections), 671.9ms
# 0: 480x640 (no detections), 561.1ms
# 0: 480x640 (no detections), 340.6ms
# 0: 480x640 (no detections), 395.3ms
# 0: 480x640 (no detections), 383.3ms
# 0: 480x640 (no detections), 465.9ms
# 0: 480x640 (no detections), 529.4ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.predict(source=0, show=True)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\engine\model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\utils\_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\engine\predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\nn\autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\nn\tasks.py:111, in BaseModel.forward(self, x, *args, **kwargs)
#     109 if isinstance(x, dict):  # for cases of training and validating while training.
#     110     return self.loss(x, *args, **kwargs)
# --> 111 return self.predict(x, *args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\nn\tasks.py:129, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     127 if augment:
#     128     return self._predict_augment(x)
# --> 129 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\nn\tasks.py:150, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     148 if profile:
#     149     self._profile_one_layer(m, x, dt)
# --> 150 x = m(x)  # run
#     151 y.append(x if m.i in self.save else None)  # save output
#     152 if visualize:
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\nn\modules\block.py:237, in C2f.forward(self, x)
#     235 def forward(self, x):
#     236     """Forward pass through C2f layer."""
# --> 237     y = list(self.cv1(x).chunk(2, 1))
#     238     y.extend(m(y[-1]) for m in self.m)
#     239     return self.cv2(torch.cat(y, 1))
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\jainb\OneDrive\Documents\Road Damage\env\Lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Notebook cell: webcam detection (inline display)
import time, cv2, numpy as np
from ultralytics import YOLO
from IPython.display import display, clear_output
from PIL import Image

model = YOLO("best.pt")
model.to("cuda")  # or "cpu"

cap = cv2.VideoCapture(0)
CONF_THRESH = 0.35

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Optionally resize
        # frame = cv2.resize(frame, (640,360))

        results = model(frame, imgsz=640, conf=CONF_THRESH, verbose=False)
        r = results[0]
        if hasattr(r, "boxes") and len(r.boxes) > 0:
            boxes = r.boxes.xyxy.cpu().numpy()
            confs = r.boxes.conf.cpu().numpy()
            cls_ids = r.boxes.cls.cpu().numpy()
            for (x1, y1, x2, y2), conf, cls in zip(boxes.astype(int), confs, cls_ids.astype(int)):
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0,168,255), 2)
                cv2.putText(frame, f"{conf:.2f}", (x1, y1-6), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1)

        # Convert BGR->RGB and display
        display_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(display_frame)
        clear_output(wait=True)
        display(img)

        # small sleep to yield to notebook
        time.sleep(0.05)
except KeyboardInterrupt:
    pass
finally:
    cap.release()
    clear_output()
    print("Stopped")
